# %% [markdown]
# # Importar librerias

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %% [markdown]
# # cargar modelo y entrenamiento

# %%
modelo = YOLO("yolo11n.pt")

# %%
modelo.train(data="/content/drive/MyDrive/Colab Notebooks/TFG/yolo/data.yaml", epochs = 50)
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/Colab Notebooks/TFG/yolo/test/images", save = True, save_txt = True )
# Out:
# image 1/3 /content/drive/MyDrive/Colab Notebooks/TFG/yolo/test/images/CBN-Pla-D4-20160728_jpg.rf.07058a284617e9ebb67ffb8ed8d966af.jpg: 640x640 16 plantas, 9.6ms
# image 2/3 /content/drive/MyDrive/Colab Notebooks/TFG/yolo/test/images/CBN-Pla-E3-20180724_jpg.rf.fab6b09fdf6b050355456ee6280f1cb8.jpg: 640x640 12 plantas, 28.8ms
# image 3/3 /content/drive/MyDrive/Colab Notebooks/TFG/yolo/test/images/LISAH-BVD-0-195-20230511_jpg.rf.7a1459733b9244eaa50b5406949809d2.jpg: 640x640 14 plantas, 22.4ms
# Speed: 5.5ms preprocess, 20.3ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 3 labels saved to runs/detect/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'planta'}
#  obb: None
#  orig_img: array([[[150, 225, 239],
#          [122, 194, 206],
#          [ 59, 121, 132],
#          ...,
# ...

# %%
infer.predict("/content/drive/MyDrive/Colab Notebooks/TFG/planta.jpeg", save = True, save_txt = True )
infer.predict("/content/drive/MyDrive/Colab Notebooks/TFG/coche.jpeg", save = True, save_txt = True )
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/TFG/planta.jpeg: 416x640 2 plantas, 67.6ms
# Speed: 3.8ms preprocess, 67.6ms inference, 8.1ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict
# 4 labels saved to runs/detect/predict/labels
#
# image 1/1 /content/drive/MyDrive/Colab Notebooks/TFG/coche.jpeg: 384x640 (no detections), 57.9ms
# Speed: 2.1ms preprocess, 57.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 4 labels saved to runs/detect/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'planta'}
#  obb: None
#  orig_img: array([[[189, 186, 165],
#          [191, 188, 167],
#          [192, 189, 168],
#          ...,
#          [200, 193, 178],
#          [200, 193, 178],
#          [200, 193, 178]],
#
#         [[185, 181, 162],
# ...

# %%
# !rm -rf /content/runs
from google.colab import files
files.download('/content/runs/detect/train2/weights/best.pt')

# %%
# realizo las bounding boxes de las imagenes con modelo yolo
modeloBox = YOLO("/content/drive/MyDrive/Colab Notebooks/TFG/yolo/yolo11n.pt")

resultados = infer.predict(source="/content/drive/MyDrive/Colab Notebooks/TFG/yolo/prueba.jpg", save=True, conf=0.3)
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/TFG/yolo/prueba.jpg: 640x640 9 plantas, 17.6ms
# Speed: 4.9ms preprocess, 17.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 5 labels saved to runs/detect/predict/labels

# %%
# Mostrar una imagen con predicciones
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/content/runs/detect/predict/prueba.jpg")
plt.imshow(img)
plt.axis("off")
plt.show()
